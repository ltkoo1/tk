# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import pandas as pd
import os

# %%
driver=webdriver.Chrome('./chromedriver.exe')
driver.get('https://www.coupang.com/vp/products/5080540471?itemId=6891539307&vendorItemId=4821810379&q=%EB%B0%A5%EC%86%A5&itemsCount=36&searchId=e9ced183180f4dd6aca6452d60d59762&rank=0&isAddedCart=')
time.sleep(5)
# Out:
# C:\Users\xorud\AppData\Local\Temp\ipykernel_3400\2186359498.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome('./chromedriver.exe')

# %%
a=driver.find_element(By.XPATH, "//*[@id='btfTab']/ul[1]/li[2]")
a.click()
# b=driver.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/div[3]/button[2]')

# %%
i = 1
j = 2
k= 1
box_list=[]
while True:
    if j > 11:
        driver.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/div[3]/button[12]').click()
        time.sleep(2)
        i = 1
        j = 2
        k += 1
    else:
        if i > 5 and j < 11:
            j += 1
            i = 1
            driver.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/div[3]/button['+str(j)+']').click()
            time.sleep(2)
        else:        
            boxes=a.find_elements(By.XPATH,'/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']')
            for box in boxes:
                ID=box.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']/div[1]/div[2]/span').text
                date=box.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']/div[1]/div[3]/div[2]').text
                product=box.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']/div[1]/div[5]').text
                title=box.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']/div[3]').text
                comment=box.find_element(By.XPATH, '/html/body/div[2]/section/div[2]/div[10]/ul[2]/li[2]/div/div[6]/section[4]/article['+str(i)+']/div[4]/div').text
                box_item={'ID' : ID, 'date':date, 'product' : product, 'title' : title,'comment' : comment}
                box_list.append(box_item)
                i += 1
            if i > 5 and j == 11:
                j += 1
    if k > 19:
        break
print(box_list)
# Out:
# [{'ID': '후기를드림 ', 'date': '2023.01.23', 'product': '쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM', 'title': '밥이 맛있어서 좋네요', 'comment': '□ 가장 좋았던 것은 기대 이상으로 밥이 찰지면서 맛있는 것 같아요. 크기도 10인용이라 밥도 넉넉하게 지을 수 있어서 기존에 사용하던 밥솥보다는 좋은 것 같아요.\n\n크기가 있음에도 증기를 배출할 때 소리가 적당해서 괜찮은 것 같습니다. 너무 시끄럽다고 느껴지지도 않고 반대로 너무 조용하지도 않은 정도라 충분히 수용할 수 있을 정도인 것 같습니다.\n\n□ 밥솥 뒷 부분을 보면 물을 모아주는 통이 있습니다. 한 번씩 비워주기만 하면 되기 때문에 관리에 있어서도 크게 불편한 부분은 없는 것 같아요.\n\n□ 다만 다른 분들이 말하는 것처럼 밥솥 뚜껑을 열 때 별다른 장치가 없어서 그런지 그냥 덜컥하고 열립니다. 그래서 항상 밥솥을 열 때마다 뚜껑을 잡고 열어야 해요.\n\n그리고 밥솥 위에 서랍장 같은 것이 있으면 크기 때문에 밥솥이 다 열리지 않는 경우도 있어서 놓는 곳을 고려하는 것도 중요할 것 같습니다.\n\n전체적으로 불편했던 것은 이 정도인데 크게 불편하다고 느낀 것은 아니어서 괜찮은 것 같습니다.\n\n□ 처음 밥솥을 받고 밥솥 메뉴에 [자동세척] 메뉴가 있어서 식초를 넣고 사용했습니다. 확실히 괜찮은 기능 같아요. 밥솥 자체적으로 있는 기능이기 때문에 사용하기에도 편하고 세척에 있어서도 나름 효과가 있는 것 같습니다.\n\n더 좋은 밥솥들이 많겠지만 가성비로는 사용하기 좋은 밥솥인 것 같습니다. 결국은 밥이 맛있어서 더 그렇게 느껴지는 것 같아요. 개인적으로 마음에 드는 제품입니다.'}, {'ID': '서*경 ', 'date': '2023.01.04', 'product': '쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM', 'title': '가성비 좋게 잘 구매한 것 같다', 'comment': '기존에 오래 사용하던 밥통이 아무리 부품을 교체해도\n압력 밥솥 되지는 않더라구요\n제품을 바꾸려는데 어떤 제품이 제일 괜찮은지 찾아 보다가\n가격이랑 비교했을 때 이 제품이 후기가 좋길래 바로 주문 했습니다\n\n배송은 다음 날 빠르게 받을 수 있었어요\n밥통이랑 가전 제품은 어떻게 배송 되나 궁금했는데\n계란판? 같은 곳에 잘 포장 되어서 받을 수 있었습니다\n같이 들어 있던 물건은 밥통, 밥 주걱, 쌀통, 사용 설명서 이렇게 들어 있었네요\n\n제품 사용한 후에 느낀 점 으로는\n\n1) 가성비가 좋다\n\n대부분 많은 식구식구가 먹는 큰 밥통일 경우에는 가격이 꽤 나가는 걸로 알고 있습니다 근데 이 제품은 유명한 브랜드인데 가격 면에서 참 괜찮은 것 같더라구요\n가격도 괜찮은데 배송도 빠르고 그래서 주문해서 사용해봤더니 제품도 참 괜찮았습니다\n일단 압력밥솥이 강해서 좋았어요 공기 가세요 나가지 않아서 밥을 할 때 잘 지어집니다\n기존에 밥통이 너무 별로였다고를 깨닫게 해준 제품이네요\n\n2) 밥 맛이 좋다\n\n일단 제품 자체 문제가 전혀 없는 것 같아요\n밥 맛이 너무 좋습니다 같은 살인데 밥통 하나 바꿨다고 밥 맛이 달라지는 신기하더라구요\n압력이 잘 되는 것 같아서 그런 것 같아요\n밥통이 밥을 잘 짓는데 더 필요한게 있나 싶습니다\n\n3) 음성이 편하다\n\n밥통을 도착할 때 음성이 항상 나오는 게 편했습니다\n지금은 무슨 상황이고 무엇을 눌렀으면 어떻게 되어 가고 있다 이런 걸 하나하나 설명해 주더라구요 아이가 사용할 때도 괜찮을 것 같아서 마음에 듭니다\n\n4) 설명이 단순하다\n\n버튼을 조작하는게 단순합니다\n크게 어려운 점이 없이 글씨가 다쓰여 있고\n그거에 맞춰서 원하는 것을 눌러 사용하면 되네요\n복잡하지 않은 밥통인 것 같아서 좋아요\n\n저는 지금까지 밥을 하고 사용하면서 딱히 불편한 점을 느끼지는 못했습니다\n위에 뚜껑 여는 것도 돌리는 것도 다 쉽게 할 수 있었어요\n하얀색보다 검은색이 때를 덜 탈 것 같아서 더 맘에 들구요\n오래 오래 사용 하도록 하겠습니다 추천 드리는 제품 중에 하나네요~~~'}, {'ID': 'Sinderella ', 'date': '2023.01.25', 'product': '쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM', 'title': '어머니집 밥솥이 말썽이라\n구매합니다\n제가 시집올때 사줬다는데\n저는 기억에 없네요\n말하는 빨간 쿠쿠모델인건 기억합니다\n그 당시에도 신모델은 아니었어요\n집집마다 있었던것 같은데\n저는 말많은건 안조아라하지만\n어머니가 몸이 불편한지라\n밥다됐다고 안내해주니\n좋다고 하시더라구요 ㅎㅎ\n지금은 그 기능이\n없는 걸로 알았는데...\n10년이 넘었으니\n맛갈때 되었네요 ^^;\n돈 보태 주신다는데\n그냥 사드러야죠\n\n포장상태 굿입니다\n새벽 배송으로 도착해서\n밥 지어먹을 걱정도 덜어주네요\n계량컵과 주걱도 구성에 넣어주시고\n제가 하고 싶네요 ㅋ\n저희껀 6인용이라 담에 10인용으로 바꿔야겠어요\n어머니는 혼자 계시지만\n한번 할때 많이 해서 냉장고 보관하시려고\n10인용을 원하시네요\n그리고 뚜껑 부분이 두껍고 묵직한것이\n압력이 잘되게 보입니다\n1등급이고\n내솥은 일단 다이아몬드 코팅입니다\n외관도 깔끔하니 괜찮네요\n\n나중에 세척하고 사용후 남겨볼께요\n\n설치후 다시 남깁니다\n말도 잘 나오고\n밥도 찰지게 잘 된다고 합니다~^^', 'comment': '6명에게 도움 됨'}, {'ID': '이*기 ', 'date': '2023.01.04', 'product': '쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM', 'title': '할머니가 좋아하세요', 'comment': '할머니댁 밥솥이 말을 잘 안듣는다고해 알아보다가 10인용 쿠쿠제품이 너무 저렴한 가격이라 한번 구경해보았는데 오호?!\n기능도 생각보다 좋는듯 하고 디자인도 예뻐 구매해서 할머니댁에\n바로 보내드렸는데. 받아서 밥 해보시고 밥이 너무 잘 되었다면서\n할머니께 전화가 왔답니다 ㅎㅎㅎ\n저렴한 가격으로 선물해 드린건데 너무 좋아하셔서 만족이구요.\n\n제품사진을 찍어주신것을 보니 제 생각보다 동그란 스타일이 아니고 길쭉? 타원형 스타일인데 할머니는 마음에 든 다 하시네요\n그리고 디자인이나 컬러도 이쁘다 하시는데 제가봐도 색상도 그렇고 무광으로 처리된 디테일들이 꽤 이쁘게 나온 듯 하구요\n\n10인용이라 사이즈는 좀 있지만 7.5kg의 무게정도로 부담없어서 할머니 혼자 사용하시기에도 큰 무리 없지 싶어요. 게다가 에너지 효율등급 1등급에 구성품으로 주걱과 청소솔등이 포함되어 있어 더 좋다고 생각했구요.\n\n가족을 생각하는 든든한 안심시스템으로 커버감지장치에 자동증기배출 압력조절 과열방지 등등 여러 기능들이 잘 나와있어 더 안심하고 사용하실 수 있을 듯 합니다. 선물하고 기분이 좋네요'}, {'ID': '김*진 ', 'date': '2022.11.14', 'product': '쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM', 'title': '우리 시부모님댁에\n밥솥하나 놓아드렸습니다.\n어찌나 밥솥 고장을 잘내시는지 ㄷㄷ\n...\n두분이 계시지만 바쁘셔서 밥을 한번에 많이 지어두시는 편이시고 주말마다 저희가 가서 같이 저녁을 먹는관계로, 10인용 밥솥을 선택했습니다.\n뭐 전에 고장난 밥솥 역시도 10인용을 사용하셨기도 하구요..\n어떤 브랜드 밥솥을 사드릴까 여쭸더니,\n쿠쿠밖에 모르시더군요 쿠쿠\n급히 필요하다고 하셔서 당연 로켓배송중에 쿠쿠로 골랐어요.\n옛날에는 이정도 스펙이면 이삼십만원은 했던것 같은데.\n요새는 ㅡ뭐 예전보다ㅡ이리 저렴할줄이야ㅎㅎ ㅡ아마 엄청난 기능들이 추가된 밥솥들이 속속 등장해서겠지요??\n배송도 다음날 뙇!\n...\n상자 내부에는 밥솥과 플라스틱 밥주걱 한개, 쌀퍼 한개가 들어있습니다.\n에너지 효율등급이 1등급이네요!\n이부분에서 또 물건 잘 산 듯 하네요!\n밥만 딱 드시는 시부모님께는 많은 기능은 필요가 없으시댔지만, 간단해도 있을 기능 다 있어요..\n...\n코팅밥솥은 코팅벗겨지면 무조건 바꿔주셔야 합니다.\n물론 밥솥 말고라도 코팅된 프라 ...

# %%
import pandas as pd
a = pd.DataFrame(box_list)
a
# Out:
#               ID        date                        product  \
# 0         후기를드림   2023.01.23  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM
# 1           서*경   2023.01.04  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM
# 2    Sinderella   2023.01.25  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM
# 3           이*기   2023.01.04  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM
# 4           김*진   2022.11.14  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM
# ..           ...         ...                            ...
# 945         황*준   2022.10.23  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM
# 946         김*숙   2022.12.14  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM
# 947         곽*영   2022.01.03  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM
# 948         A*l   2023.01.28  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FSM
# 949         정*미   2022.11.07  쿠쿠 10인용 전기압력밥솥, CRP-QS1020FGM
#
#                                                  title  \
# 0                                          밥이 맛있어서 좋네요
# 1                                    가성비 좋게 잘 구매한 것 같다
# 2    어머니집 밥솥이 말썽이라\n구매합니다\n제가 시집올때 사줬다는데\n저는 기억에 없네...
# 3                                           할머니가 좋아하세요
# 4    우리 시부모님댁에\n밥솥하나 놓아드렸습니다.\n어찌나 밥솥 고장을 잘내시는지 ㄷㄷ\...
# ..                                                 ...
# 945                                         조아요~~~~~~~
# 946                                    착한가격 빠른배송 감사합니다
# 947                          배송완전빨라서좋았어요 엄마선물했는데좋아하셯어요
# 948                                           배송이 빨라요.
# 949                                             반품해주세요
#
#                                                comment
# 0    □ 가장 좋았던 것은 기대 이상으로 밥이 찰지면서 맛있는 것 같아요. 크기도 10인...
# 1    기존에 오래 사용하던 밥통이 아무리 부품을 교체해도\n압력 밥솥 되지는 않더라구요\...
# 2                                            6명에게 도움 됨
# 3    할머니댁 밥솥이 말을 잘 안듣는다고해 알아보다가 10인용 쿠쿠제품이 너무 저렴한 가...
# 4                                           57명에게 도움 됨
# ..                                                 ...
# 945
# 946
# 947
# 948
# 949  쿠팡믿고 쿠쿠압력솥 시골 부모님께 사드렸는데\n저희 엄마말씀이 지금까지 밥솥쓰면서 ...
#
# [950 rows x 5 columns]

# %%
a.to_csv('밥솥1.csv', index = False)
